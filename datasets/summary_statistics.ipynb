# %%
import itertools
import multiprocessing
import random

import networkx as nx
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([
        ('Facebook Northwestern University', '', 'socfb-Northwestern25/socfb-Northwestern25.edges.gz'),
        ('IMDB movies and actors', '', 'imdb/actors_movies.edges.gz'),
        ('IMDB actors costar', 'W', 'imdb/actors_costar.edges.gz'),
        ('Twitter US politics', 'DW', 'icwsm_polarization/retweet-digraph.edges.gz'),
        ('Enron Email', 'DW', 'email-Enron/email-Enron.edges.gz'),
        ('Enron Executive Email', '', 'ia-enron-only/ia-enron-only.edges'),
        ('Wikipedia math', 'D', 'enwiki_math/enwiki_math.edges.gz'),
        ('Internet routers', '', 'tech-RL-caida/tech-RL-caida.edges.gz'),
        ('US air transportation', '', 'openflights/openflights_usa.edges.gz'),
        ('World air transportation', '', 'openflights/openflights_world.edges.gz'),
        ('Yeast protein interactions', '', 'bio-yeast-protein-inter/bio-yeast-protein-inter.edges'),
        ('C. elegans brain', 'DW', 'celegansneural/celegansneural.edges'),
        ('Everglades ecological food web', 'DW', 'eco-everglades/eco-everglades.edges'),
    ],
    columns=['Name', 'Type', 'File'],
)

# %%
df = df.set_index('Name')

# %%
df.head()
# Out:
#                                  Type  \
# Name
# Facebook Northwestern University
# IMDB movies and actors
# IMDB actors costar                  W
# Twitter US politics                DW
# Enron Email                        DW
#
#                                                                                File
# Name
# Facebook Northwestern University  socfb-Northwestern25/socfb-Northwestern25.edge...
# IMDB movies and actors                                  imdb/actors_movies.edges.gz
# IMDB actors costar                                      imdb/actors_costar.edges.gz
# Twitter US politics                     icwsm_polarization/retweet-digraph.edges.gz
# Enron Email                                        email-Enron/email-Enron.edges.gz

# %%
def single_source_average_path_length(G, node):
    return np.average(list(nx.single_source_shortest_path_length(G, node).values()))

def estimated_average_path_length(G, N_sample=100):
    if G.is_directed():
        components = nx.strongly_connected_component_subgraphs(G)
    else:
        components = nx.connected_component_subgraphs(G)
    core = max(components, key=len)
    
    if core.number_of_nodes() <= N_sample:
        sampled_nodes = list(core.nodes)
    else:
        sampled_nodes = random.sample(list(core.nodes), N_sample)
    
    with multiprocessing.Pool() as pool:
        args = ((core, node) for node in sampled_nodes)
        node_apls = pool.starmap(single_source_average_path_length, args)
    
    return np.average(node_apls)

# %%
updates = []
for idx, row in df.iterrows():
    fname = row['File']
    print(idx)
    if 'graphml' in fname:
        G = nx.read_graphml(fname)
    else:
        graph_class = nx.DiGraph() if 'D' in row['Type'] else nx.Graph()
        data_spec = [('weight', float)] if 'W' in row['Type'] else False
        G = nx.read_edgelist(fname, create_using=graph_class, data=data_spec)
        
    N = G.number_of_nodes()
    
    if G.is_multigraph():
        MG = G
        G = nx.DiGraph() if MG.is_directed() else nx.Graph()
        G.add_edges_from((u,v) for u,v,i in MG.edges)
  
    L = G.number_of_edges()
        
    degree_view = G.in_degree if G.is_directed() else G.degree
    degrees = np.array([d for n,d in degree_view])
    
    cc = nx.average_clustering(G.to_undirected())
    
    # This corresponds to the definition of heterogeneity given in the book.
    # Note that this definition may differ from that from other sources.
    heterogeneity = (degrees ** 2).mean() / degrees.mean() ** 2
    
    updates.append({
        'Name': idx,
        'Nodes': N,
        'Links': L,
        'Density': nx.density(G),
        'Average Degree': degrees.mean(),
        'Maximum Degree': degrees.max(),
        'Heterogeneity': heterogeneity,
        'Clustering': cc,
        'Average Path Length': estimated_average_path_length(G, N_sample=1000),
    })
# Out:
# Facebook Northwestern University
# IMDB movies and actors
# IMDB actors costar
# Twitter US politics
# Enron Email
# Enron Executive Email
# Wikipedia math
# Internet routers
# US air transportation
# World air transportation
# Yeast protein interactions
# C. elegans brain
# Everglades ecological food web

# %%
new_df = pd.DataFrame.from_records(updates, index='Name')

# %%
df = df.join(new_df)

# %%
df.head()
# Out:
#                                  Type  \
# Name
# Facebook Northwestern University
# IMDB movies and actors
# IMDB actors costar                  W
# Twitter US politics                DW
# Enron Email                        DW
#
#                                                                                File  \
# Name
# Facebook Northwestern University  socfb-Northwestern25/socfb-Northwestern25.edge...
# IMDB movies and actors                                  imdb/actors_movies.edges.gz
# IMDB actors costar                                      imdb/actors_costar.edges.gz
# Twitter US politics                     icwsm_polarization/retweet-digraph.edges.gz
# Enron Email                                        email-Enron/email-Enron.edges.gz
#
#                                   Average Degree  Average Path Length  \
# Name
# Facebook Northwestern University       92.426800             2.718520
# IMDB movies and actors                  3.269754            12.148362
# IMDB actors costar                      8.025225             6.849723
# Twitter US politics                     2.618571             5.585333
# Enron Email                             3.688632             3.613747
#
#                                   Clustering   Density  Heterogeneity  \
# Name
# Facebook Northwestern University    0.237991  0.008748       1.835828
# IMDB movies and actors              0.000000  0.000006       5.406334
# IMDB actors costar                  0.667560  0.000032       4.570261
# Twitter US politics                 0.026153  0.000142       8.298196
# Enron Email                         0.119342  0.000042      17.436859
#
#                                     Links  Maximum Degree   Nodes
# Name
# Facebook Northwestern University   488337            2105   10567
# IMDB movies and actors             921160             800  563443
# IMDB actors costar                1015187             456  252999
# Twitter US politics                 48365             204   18470
# Enron Email                        321918            1338   87273

# %% [markdown]
# ## Chapter 1
# * Nodes
# * Links
# * Density
# * Average degree

# %%
ch1 = df[['Nodes', 'Links', 'Density', 'Average Degree']]
ch1
# Out:
#                                    Nodes    Links   Density  Average Degree
# Name
# Facebook Northwestern University   10567   488337  0.008748       92.426800
# IMDB movies and actors            563443   921160  0.000006        3.269754
# IMDB actors costar                252999  1015187  0.000032        8.025225
# Twitter US politics                18470    48365  0.000142        2.618571
# Enron Email                        87273   321918  0.000042        3.688632
# Enron Executive Email                143      623  0.061361        8.713287
# Wikipedia math                     15220   194103  0.000838       12.753154
# Internet routers                  190914   607610  0.000033        6.365274
# US air transportation                546     2781  0.018691       10.186813
# World air transportation            3179    18617  0.003685       11.712488
# Yeast protein interactions          1870     2277  0.001303        2.435294
# C. elegans brain                     297     2345  0.026674        7.895623
# Everglades ecological food web        69      916  0.195226       13.275362

# %%
print(ch1.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &   Nodes &    Links &   Density &  Average Degree \\
# Name                             &         &          &           &                 \\
# \midrule
# Facebook Northwestern University &   10567 &   488337 &  0.008748 &       92.426800 \\
# IMDB movies and actors           &  563443 &   921160 &  0.000006 &        3.269754 \\
# IMDB actors costar               &  252999 &  1015187 &  0.000032 &        8.025225 \\
# Twitter US politics              &   18470 &    48365 &  0.000142 &        2.618571 \\
# Enron Email                      &   87273 &   321918 &  0.000042 &        3.688632 \\
# Enron Executive Email            &     143 &      623 &  0.061361 &        8.713287 \\
# Wikipedia math                   &   15220 &   194103 &  0.000838 &       12.753154 \\
# Internet routers                 &  190914 &   607610 &  0.000033 &        6.365274 \\
# US air transportation            &     546 &     2781 &  0.018691 &       10.186813 \\
# World air transportation         &    3179 &    18617 &  0.003685 &       11.712488 \\
# Yeast protein interactions       &    1870 &     2277 &  0.001303 &        2.435294 \\
# C. elegans brain                 &     297 &     2345 &  0.026674 &        7.895623 \\
# Everglades ecological food web   &      69 &      916 &  0.195226 &       13.275362 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Chapter 2
#
# * Nodes
# * Links
# * APL
# * CC

# %%
ch2 = df[['Nodes', 'Links', 'Clustering', 'Average Path Length']]
ch2
# Out:
#                                    Nodes    Links  Clustering  \
# Name
# Facebook Northwestern University   10567   488337    0.237991
# IMDB movies and actors            563443   921160    0.000000
# IMDB actors costar                252999  1015187    0.667560
# Twitter US politics                18470    48365    0.026153
# Enron Email                        87273   321918    0.119342
# Enron Executive Email                143      623    0.433907
# Wikipedia math                     15220   194103    0.307440
# Internet routers                  190914   607610    0.158173
# US air transportation                546     2781    0.493045
# World air transportation            3179    18617    0.490542
# Yeast protein interactions          1870     2277    0.067168
# C. elegans brain                     297     2345    0.292363
# Everglades ecological food web        69      916    0.552105
#
#                                   Average Path Length
# Name
# Facebook Northwestern University             2.718520
# IMDB movies and actors                      12.148362
# IMDB actors costar                           6.849723
# Twitter US politics                          5.585333
# Enron Email                                  3.613747
# Enron Executive Email                        2.946257
# Wikipedia math                               3.919790
# Internet routers                             7.009731
# US air transportation                        3.191425
# World air transportation                     3.950245
# Yeast protein interactions                   6.785239
# C. elegans brain                             3.977609
# Everglades ecological food web               2.173056

# %%
print(ch2.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &   Nodes &    Links &  Clustering &  Average Path Length \\
# Name                             &         &          &             &                      \\
# \midrule
# Facebook Northwestern University &   10567 &   488337 &    0.237991 &             2.718520 \\
# IMDB movies and actors           &  563443 &   921160 &    0.000000 &            12.148362 \\
# IMDB actors costar               &  252999 &  1015187 &    0.667560 &             6.849723 \\
# Twitter US politics              &   18470 &    48365 &    0.026153 &             5.585333 \\
# Enron Email                      &   87273 &   321918 &    0.119342 &             3.613747 \\
# Enron Executive Email            &     143 &      623 &    0.433907 &             2.946257 \\
# Wikipedia math                   &   15220 &   194103 &    0.307440 &             3.919790 \\
# Internet routers                 &  190914 &   607610 &    0.158173 &             7.009731 \\
# US air transportation            &     546 &     2781 &    0.493045 &             3.191425 \\
# World air transportation         &    3179 &    18617 &    0.490542 &             3.950245 \\
# Yeast protein interactions       &    1870 &     2277 &    0.067168 &             6.785239 \\
# C. elegans brain                 &     297 &     2345 &    0.292363 &             3.977609 \\
# Everglades ecological food web   &      69 &      916 &    0.552105 &             2.173056 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Chapter 3
# * Nodes
# * Links
# * Density
# * Average degree
# * Maximum degree
# * Heterogeneity

# %%
ch3 = df[['Nodes', 'Links', 'Average Degree', 'Maximum Degree', 'Heterogeneity']]
ch3
# Out:
#                                    Nodes    Links  Average Degree  \
# Name
# Facebook Northwestern University   10567   488337       92.426800
# IMDB movies and actors            563443   921160        3.269754
# IMDB actors costar                252999  1015187        8.025225
# Twitter US politics                18470    48365        2.618571
# Enron Email                        87273   321918        3.688632
# Enron Executive Email                143      623        8.713287
# Wikipedia math                     15220   194103       12.753154
# Internet routers                  190914   607610        6.365274
# US air transportation                546     2781       10.186813
# World air transportation            3179    18617       11.712488
# Yeast protein interactions          1870     2277        2.435294
# C. elegans brain                     297     2345        7.895623
# Everglades ecological food web        69      916       13.275362
#
#                                   Maximum Degree  Heterogeneity
# Name
# Facebook Northwestern University            2105       1.835828
# IMDB movies and actors                       800       5.406334
# IMDB actors costar                           456       4.570261
# Twitter US politics                          204       8.298196
# Enron Email                                 1338      17.436859
# Enron Executive Email                         42       1.482948
# Wikipedia math                              5171      38.210205
# Internet routers                            1071       5.963275
# US air transportation                        153       5.347495
# World air transportation                     246       5.509073
# Yeast protein interactions                    56       2.687747
# C. elegans brain                             134       2.713711
# Everglades ecological food web                63       2.236306

# %%
print(ch3.to_latex())
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &   Nodes &    Links &  Average Degree &  Maximum Degree &  Heterogeneity \\
# Name                             &         &          &                 &                 &                \\
# \midrule
# Facebook Northwestern University &   10567 &   488337 &       92.426800 &            2105 &       1.835828 \\
# IMDB movies and actors           &  563443 &   921160 &        3.269754 &             800 &       5.406334 \\
# IMDB actors costar               &  252999 &  1015187 &        8.025225 &             456 &       4.570261 \\
# Twitter US politics              &   18470 &    48365 &        2.618571 &             204 &       8.298196 \\
# Enron Email                      &   87273 &   321918 &        3.688632 &            1338 &      17.436859 \\
# Enron Executive Email            &     143 &      623 &        8.713287 &              42 &       1.482948 \\
# Wikipedia math                   &   15220 &   194103 &       12.753154 &            5171 &      38.210205 \\
# Internet routers                 &  190914 &   607610 &        6.365274 &            1071 &       5.963275 \\
# US air transportation            &     546 &     2781 &       10.186813 &             153 &       5.347495 \\
# World air transportation         &    3179 &    18617 &       11.712488 &             246 &       5.509073 \\
# Yeast protein interactions       &    1870 &     2277 &        2.435294 &              56 &       2.687747 \\
# C. elegans brain                 &     297 &     2345 &        7.895623 &             134 &       2.713711 \\
# Everglades ecological food web   &      69 &      916 &       13.275362 &              63 &       2.236306 \\
# \bottomrule
# \end{tabular}

# %%
df.to_csv('summary_statistics.csv')
