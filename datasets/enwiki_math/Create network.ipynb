# %% [markdown]
# Files c.f. https://dumps.wikimedia.org/simplewiki/20180220/

# %%
import gzip
import re

from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://claydavi:@/enwiki')

# %% [markdown]
# We need the `page` and `categorylinks` tables loaded; we can use stream processing for the links.
#
# `math_page` is a subset of the wikipedia `page` table, with pages in namespace 0 linked to any category matching `%athematic%`
#
# ```sql
# create temporary table math_page_ids as
# select distinct(cl_from) as page_id
# from categorylinks
# where cl_type='page'
#     and cl_to like '%athematic%';
# ```
# ```sql
# create table math_page as
# select page.page_id, page_title, page_is_redirect
# from page
#     join math_page_ids
#     on page.page_id = math_page_ids.page_id
# where page_namespace = 0;
# ```

# %%
result = engine.execute('select page_id from math_page')
page_ids = {x[0] for x in result}

# %%
len(page_ids)
# Out:
# 15992

# %%
result = engine.execute('select page_title, page_id from math_page')
page_titles = {k.decode('utf8'): v for k, v in result}

# %%
len(page_titles)
# Out:
# 15992

# %%
columns = ['pl_from', 'pl_namespace', 'pl_title', 'pl_from_namespace']

# %%
links = set()
line_num = 0

# %%
rex = re.compile(r"\((\d+),(\d+),'(.+?)',(\d+)\)")
with gzip.open('enwiki-20180220-pagelinks.sql.gz', 'rt', encoding='latin1') as f:
    for idx, line in enumerate(f):
        if idx % 100 == 0:
            print('line %i' % idx)
        # if idx < line_num:
        #     continue
        line_num = idx
        if line.startswith('INSERT INTO'):
            data = rex.findall(line)
            # print(len(data))
            for row in data:
                try:
                    page_id = int(row[0])
                    page_title = row[2]
                except ValueError:
                    print(datum, row)
                    print(line)
                    raise
                if page_id in page_ids and page_title in page_titles:
                    links.add((page_id, page_titles[page_title]))
# Out:
# line 0
# line 100
# line 200
# line 300
# line 400
# line 500
# line 600
# line 700
# line 800
# line 900
# line 1000
# line 1100
# line 1200
# line 1300
# line 1400
# line 1500
# line 1600
# line 1700
# line 1800
# line 1900
# line 2000
# line 2100
# line 2200
# line 2300
# line 2400
# line 2500
# line 2600
# line 2700
# line 2800
# line 2900
# line 3000
# line 3100
# line 3200
# line 3300
# line 3400
# line 3500
# line 3600
# line 3700
# line 3800
# line 3900
# line 4000
# line 4100
# line 4200
# line 4300
# line 4400
# line 4500
# line 4600
# line 4700
# line 4800
# line 4900
# line 5000
# line 5100
# line 5200
# line 5300
# line 5400
# line 5500
# line 5600
# line 5700
# line 5800
# line 5900
# line 6000
# line 6100
# line 6200
# line 6300
# line 6400
# line 6500
# line 6600
# line 6700
# line 6800
# line 6900
# line 7000
# line 7100
# line 7200
# line 7300
# line 7400
# line 7500
# line 7600
# line 7700
# line 7800
# line 7900
# line 8000
# line 8100
# line 8200
# line 8300
# line 8400
# line 8500
# line 8600
# line 8700
# line 8800
# line 8900
# line 9000
# line 9100
# line 9200
# line 9300
# line 9400
# line 9500
# line 9600
# line 9700
# line 9800
# line 9900
# line 10000
# line 10100
# line 10200
# line 10300
# line 10400
# line 10500
# line 10600
# line 10700
# line 10800
# line 10900
# line 11000
# line 11100
# line 11200
# line 11300
# line 11400
# line 11500
# line 11600
# line 11700
# line 11800
# line 11900
# line 12000
# line 12100
# line 12200
# line 12300
# line 12400
# line 12500
# line 12600
# line 12700
# line 12800
# line 12900
# line 13000
# line 13100
# line 13200
# line 13300
# line 13400
# line 13500
# line 13600
# line 13700
# line 13800
# line 13900
# line 14000
# line 14100
# line 14200
# line 14300
# line 14400
# line 14500
# line 14600
# line 14700
# line 14800
# line 14900
# line 15000
# line 15100
# line 15200
# line 15300
# line 15400
# line 15500
# line 15600
# line 15700
# line 15800
# line 15900
# line 16000
# line 16100
# line 16200
# line 16300
# line 16400
# line 16500
# line 16600
# line 16700
# line 16800
# line 16900
# line 17000
# line 17100
# line 17200
# line 17300
# line 17400
# line 17500
# line 17600
# line 17700
# line 17800
# line 17900
# line 18000
# line 18100
# line 18200
# line 18300
# line 18400
# line 18500
# line 18600
# line 18700
# line 18800
# line 18900
# line 19000
# line 19100
# line 19200
# line 19300
# line 19400
# line 19500
# line 19600
# line 19700
# line 19800
# line 19900
# line 20000
# line 20100
# line 20200
# line 20300
# line 20400
# line 20500
# line 20600
# line 20700
# line 20800
# line 20900
# line 21000
# line 21100
# line 21200
# line 21300
# line 21400
# line 21500
# line 21600
# line 21700
# line 21800
# line 21900
# line 22000
# line 22100
# line 22200
# line 22300
# line 22400
# line 22500
# line 22600
# line 22700
# line 22800
# line 22900
# line 23000
# line 23100
# line 23200
# line 23300
# line 23400
# line 23500
# line 23600
# line 23700
# line 23800
# line 23900
# line 24000
# line 24100
# line 24200
# line 24300
# line 24400
# line 24500
# line 24600
# line 24700
# line 24800
# line 24900
# line 25000
# line 25100
# line 25200
# line 25300
# line 25400
# line 25500
# line 25600
# line 25700
# line 25800
# line 25900
# line 26000
# line 26100
# line 26200
# line 26300
# line 26400
# line 26500
# line 26600
# line 26700
# line 26800
# line 26900
# line 27000
# line 27100
# line 27200
# line 27300
# line 27400
# line 27500
# line 27600
# line 27700
# line 27800
# line 27900
# line 28000
# line 28100
# line 28200
# line 28300
# line 28400
# line 28500
# line 28600
# line 28700
# line 28800
# line 28900
# line 29000
# line 29100
# line 29200
# line 29300
# line 29400
# line 29500
# line 29600
# line 29700
# line 29800
# line 29900
# line 30000
# line 30100
# line 30200
# line 30300
# line 30400
# line 30500
# line 30600
# line 30700
# line 30800
# line 30900
# line 31000
# line 31100
# line 31200
# line 31300
# line 31400
# line 31500
# line 31600
# line 31700
# line 31800
# line 31900
# line 32000
# line 32100
# line 32200
# line 32300
# line 32400
# line 32500
# line 32600
# line 32700
# line 32800
# line 32900
# line 33000
# line 33100
# line 33200
# line 33300
# line 33400
# line 33500
# line 33600
# line 33700
# line 33800
# line 33900
# line 34000
# line 34100
# line 34200
# line 34300
# line 34400
# line 34500
# line 34600
# line 34700
# line 34800
# line 34900
# line 35000
# line 35100
# line 35200
# line 35300
# line 35400
# line 35500
# line 35600
# line 35700
# line 35800
# line 35900
# line 36000
# line 36100
# line 36200
# line 36300
# line 36400
# line 36500
# line 36600
# line 36700
# line 36800
# line 36900
# line 37000
# line 37100
# line 37200
# line 37300
# line 37400
# line 37500
# line 37600
# line 37700
# line 37800
# line 37900
# line 38000
# line 38100
# line 38200
# line 38300
# line 38400
# line 38500
# line 38600
# line 38700
# line 38800
# line 38900
# line 39000
# line 39100
# line 39200
# line 39300
# line 39400
# line 39500
# line 39600
# line 39700
# line 39800
# line 39900
# line 40000
# line 40100
# line 40200
# line 40300
# line 40400
# line 40500
# line 40600
# line 40700
# line 40800
# line 40900
# line 41000

# %%
line_num
# Out:
# 41061

# %%
len(links)
# Out:
# 194368

# %%
page_titles
# Out:
# {'Wojciech_Zaremba': 51237053,
#  'Mathematics_&_Mechanics_of_Solids': 31834571,
#  'Allan_J._C._Cunningham': 1572371,
#  'Amplitude_integrated_electroencephalography': 49895047,
#  'Particular_values_of_the_gamma_function': 4239318,
#  'Giulio_Ascoli': 3855752,
#  "Lévy's_constant": 1067914,
#  'Shoshana_Kamin': 24401034,
#  'James_Lockhart_(banker)': 50061166,
#  'Lars_Edvard_Phragmén': 29769882,
#  'Raymond_Louis_Wilder': 4297377,
#  'Paul_Glaister': 49149830,
#  'Hekat_(unit)': 9098286,
#  'Karl-Theodor_Sturm': 31696372,
#  'Red_auxiliary_number': 19985265,
#  "Jamshidian's_trick": 31954655,
#  'Statistical_arbitrage': 1137949,
#  'Cutting_sequence': 33509133,
#  'Multivalued_treatment': 54248486,
#  'Jonathan_Borwein': 1145010,
#  'Ludvig_Faddeev': 4854639,
#  'Pieter_Hendrik_Schoute': 6022750,
#  'Christopher_Clavius': 633645,
#  'Su_Buqing': 209460,
#  'Thomas_Urquhart': 734814,
#  'Boris_Zilber': 47992829,
#  'Raymond_L._Johnson': 53709624,
#  'Des_MacHale': 3681770,
#  'Hellenic_Mathematical_Society': 945503,
#  'Postcondition': 39291,
#  'Rashid_Ahmad': 31764209,
#  'Langley’s_Adventitious_Angles': 43805888,
#  'Volatility_smile': 1533070,
#  'Richard_P._Stanley': 1633397,
#  'Kenneth_O._May': 719577,
#  'List_of_mathematic_operators': 8339650,
#  'Alexander_Goncharov': 32114133,
#  'Pepijn_van_Erp': 52705829,
#  'Vladimir_Gennadievich_Sprindzuk': 50924839,
#  'Cauchy–Schwarz_inequality': 38128,
#  'Heliodorus_of_Larissa': 29763822,
#  'Harald_Grobner': 53271946,
#  'Proposition': 81094,
#  'Peter_Cameron_(mathematician)': 8007266,
#  'Cecilia_Krieger': 11581652,
#  'Disentanglement_puzzle': 211757,
#  'P-adic_cohomology': 46927724,
#  'Irene_Fischer': 24864343,
#  'Reform_mathematics': 9902256,
#  'Eugene_M._Luks': 38404291,
#  'International_Mathematical_Olympiad': 82208,
#  'René_Descartes': 25525,
#  'Kātyāyana': 4494867,
#  'List_of_things_named_after_André_Weil': 39490837,
#  'Henry_Burchard_Fine': 6345064,
#  'Helmholtz_theorem': 3582270,
#  'Fourier_division': 21281625,
#  'Haidao_Suanjing': 15419368,
#  'Complete_Fermi–Dirac_integral': 406922,
#  'Cos_X': 38013652,
#  'Henry_Rawlingson_Carr': 10051179,
#  "Neil_O'Connell": 31984270,
#  'Anthony_Weston': 34837321,
#  'Paper_bag_problem': 2035985,
#  'Martin_David_Kruskal': 1084397,
#  'L¹_space': 42145291,
#  'Networks_and_Heterogeneous_Media': 46772079,
#  'James_Hann': 40752524,
#  'Naisyin_Wang': 55542969,
#  'Michael_Maschler': 19158681,
#  'Big_O_notation': 44578,
#  'Peter_M._Neumann': 7151472,
#  'Robert_Evert_Stong': 34712394,
#  'Commutation_(neurophysiology)': 5129781,
#  'Paul_Tseng': 25004404,
#  'James_G._Oldroyd': 1779027,
#  'Total_curvature': 19172363,
#  'Sigve_Tjøtta': 24897365,
#  "Chebyshev's_theorem": 249243,
#  'Word_problem_(mathematics_education)': 297013,
#  'List_of_complex_analysis_topics': 340617,
#  'Esmail_Babolian': 28170218,
#  'Henry_Louis_Rietz': 38396709,
#  'Donald_Cochrane_(economist)': 44378818,
#  'Queueing_Systems': 30629354,
#  'Juris_Hartmanis': 305842,
#  'Studia_Mathematica': 1804931,
#  'Herman_Valentiner': 33289397,
#  'Bijection,_injection_and_surjection': 1830142,
#  'Patrick_Murdoch': 23451638,
#  'Magnus_Pegel': 21874923,
#  'Artificial_neural_network': 21523,
#  'Elizabeth_Buchanan_Cowley': 48126834,
#  'List_of_things_named_after_Fibonacci': 25169071,
#  'Moritz_Cantor': 307975,
#  'Nigel_Kalton': 34221149,
#  'Wilhelm_Winkler': 51347294,
#  'Victor_Ginzburg': 14995490,
#  'Étienne_Bézout': 96017,
#  'Valérie_Berthé': 56550279,
#  'Mathematical_Biosciences_Institute': 33153324,
#  'Abel–Goncharov_interpolation': 35216223,
#  'David_Rothman_(statistician)': 29405707,
#  'Franz_Woepcke': 20650959,
#  'Antipater_(astrologer)': 49268287,
#  'Nitrogen_rule': 4004777,
#  'SolverStudio': 50087102,
#  'Diagonalization': 59672,
#  'James_Clerk_Maxwell': 28989696,
#  'Robert_Tijdeman': 9006087,
#  'David_Borwein': 4860688,
#  'Duncan_Sommerville': 8276753,
#  'Real_coordinate_space': 1482083,
#  'Hemicontinuity': 2945778,
#  'Timeline_of_women_in_mathematics_in_the_United_States': 41391212,
#  'EEGLAB': 9085803,
#  'Exposed_point': 45357429,
#  'Agata_Smoktunowicz': 44906201,
#  'T-norm': 2099179,
#  'Osip_Ivanovich_Somov': 26448780,
#  'Alice_Lee_(mathematician)': 39502937,
#  'Fragment_(logic)': 43571557,
#  'Automated_efficiency_model': 53341083,
#  'Protractor': 837995,
#  'John_Tukey': 415974,
#  'Jan_Mikołaj_Smogulecki': 22708813,
#  'David_Ben-Zvi': 52559029,
#  'Logical_equivalence': 169324,
#  'John_Kersey_the_elder': 23447922,
#  'Hierarchical_decision_process': 20591151,
#  'Tatyana_Pavlovna_Ehrenfest': 3969942,
#  'Semyon_Alesker': 32595640,
#  'Francis_Skinner': 465198,
#  'Shambhu_Dayal_Sinvhal': 46996476,
#  'James_Key_Caird': 1048993,
#  'Chunking_(division)': 27438986,
#  'Jim_Gray_(computer_scientist)': 308367,
#  'Andrew_Munro_(mathematician)': 39124656,
#  'Andrew_Wiles': 2027,
#  'William_C._Waterhouse': 26101498,
#  'Suresh_P._Sethi': 22199154,
#  'Robert_Alexander_Rankin': 5884314,
#  'Global_Digital_Mathematics_Library': 49336576,
#  'Prime_ideal_theorem': 834957,
#  'Q-analysis': 19281610,
#  'Squaring_the_circle': 201359,
#  'Laurence_Chisholm_Young': 9620408,
#  'Johann_Matthias_Hase': 4308976,
#  'Kurtosis': 16848,
#  'Jean-Paul_Bergeron': 53291183,
#  'Yitzhak_Katznelson': 5643045,
#  'Charles_Cook_(academic)': 34647947,
#  'Hans-Joachim_Nastold': 36982769,
#  'Propositional_function': 229146,
#  'Samarendra_Nath_Roy': 3894736,
#  'Yuri_Luchko': 41332872,
#  'Joseph-François_Marie': 49918091,
#  'Max_Rössler': 55634269,
#  'Raymond_Ogden': 49709981,
#  'Ronald_L._Iman': 710187,
#  'Weapons_of_Math_Destruction': 54256085,
#  'Rahim_Gaziyev': 19391913,
#  'G._I._Taylor': 610133,
#  'Beppo_Levi': 8718312,
#  'Edward_J._Hannan': 26707502,
#  'Sergei_Vostokov': 47635690,
#  'Jean_van_Heijenoort': 2137251,
#  'History_of_the_function_concept': 36595472,
#  'Hyperbolic_trigonometry': 4778172,
#  'William_Fogg_Osgood': 6340621,
#  'Error_term': 4229275,
#  'Arif_Zaman': 9468990,
#  'Matthew_Stewart_(mathematician)': 409327,
#  'Werner_Weber_(mathematician)': 53613774,
#  'Giovanni_Antonelli': 7598558,
#  'Eric_Harold_Neville': 27393555,
#  'Daniel_Huybrechts': 48322758,
#  'Edoardo_Vesentini': 34938661,
#  "Gelfond's_constant": 1984963,
#  'Navier–Stokes_existence_and_smoothness': 6013654,
#  'Paul_Vojta': 1802312,
#  'GNU_Linear_Programming_Kit': 1009552,
#  'Montserrat_Teixidor_i_Bigas': 38849883,
#  "Newton's_minimal_resistance_problem": 54492474,
#  'Tony_Gardiner': 31912608,
#  'Romaka_Siddhanta': 10205957,
#  'Ioan_Mire_Melik': 35718248,
#  'W._R._(Red)_Alford': 7568644,
#  'List_of_properties_of_sets_of_reals': 2236863,
#  'Platon_Poretsky': 3033920,
#  "Maurice_L'Abbé": 49321993,
#  'Arctg_(trigonometric_function)': 49636484,
#  'Real_Analysis_Exchange': 30440518,
#  'Peter_Andreas_Hansen': 205501,
#  "Knaster's_condition": 32926406,
#  'Évariste_Galois': 9815,
#  "Wilkie's_theorem": 22304328,
#  'Cahiers_de_Topologie_et_Géométrie_Différentielle_Catégoriques': 1595063,
#  'Konrad_Osterwalder': 19188374,
#  'Indicator_function': 240790,
#  'APMonitor': 15358001,
#  'Charles_E._M._Pearce': 7674499,
#  'Fifth-order_Korteweg–de_Vries_equation': 42063219,
#  'Covariant_derivative': 431848,
#  'Anna_Rönström': 49934850,
#  'Volume-weighted_average_price': 1869136,
#  'Glossary_of_cryptographic_keys': 1070569,
#  'Julia_Pevtsova': 54408249,
#  'List_of_mathematical_properties_of_points': 33086275,
#  'Shell_theorem': 2025989,
#  'Mary_Ellen_Rudin': 2976742,
#  'Jakob_Steiner': 567445,
#  'Steve_Mould': 42456725,
#  'State-space_representation': 548156,
#  'John_C._Oxtoby': 47435441,
#  'Cohomology_of_algebras': 31575438,
#  'Eugene_P._Northrop': 56167324,
#  'Ibn_al-Durayhim': 35575543,
#  'George_Lakoff': 46135,
#  'Computing_(journal)': 20814010,
#  'Educational_Studies_in_Mathematics': 20755852,
#  'List_of_square_roots': 32798788,
#  'Conditional_convergence': 1198956,
#  'Herwart_von_Hohenburg': 20952682,
#  'Mathematical_elimination': 23522969,
#  'Robert_Rumely': 24708114,
#  'Martin_Charles_Golumbic': 14227148,
#  'Achyuta_Pisharati': 2793081,
#  'Flora_Philip': 41259702,
#  'Nikolay_Sergeyevich_Krylov': 4439739,
#  'Ramchundra': 22936087,
#  'Paul_Schupp': 54677806,
#  'Intermediate_Math_League_of_Eastern_Massachusetts': 18305757,
#  'Uniformization': 2185166,
#  'Journal_of_Graph_Algorithms_and_Applications': 31063708,
#  'Set_(mathematics)': 26691,
#  'Christian_August_Hausen': 9728740,
#  'Brockway_McMillan': 24341057,
#  'Curvature': 60770,
#  'Everything_and_More_(book)': 1198398,
#  'Paul_Stäckel': 9075676,
#  'Vladimir_Abramovich_Rokhlin': 7703611,
#  'Discriminated_union': 576300,
#  'Deduction_theorem': 480010,
#  'Peano_axioms': 25005,
#  'Craig_interpolation': 2056790,
#  'Unit_commitment_problem_in_electrical_power_production': 47290184,
#  'William_Duke_(mathematician)': 50393209,
#  'Fan_Chung': 246562,
#  'Energy_modeling': 50413747,
#  'Unimodular': 735439,
#  'Carlo_Severini': 26527105,
#  'John_Cayo_Evans': 21870555,
#  'Émile_Picard': 42000,
#  'Elihu_Root': 287468,
#  'Encyclopedia_of_the_Brethren_of_Purity': 4849234,
#  'Friedrich_Wilhelm_August_Ludwig_Kiepert': 35216749,
#  'Marjorie_Lee_Browne': 8459839,
#  'Wolfram_Demonstrations_Project': 13989702,
#  'Alexander_Kronrod': 4843650,
#  'Agnes_E._Wells': 54570072,
#  'Susan_Horn': 53180443,
#  'Peter_Ozsváth': 5027843,
#  'Esther_Seiden': 55791412,
#  'Hans_Petersson': 9079432,
#  "Darboux's_formula": 14603715,
#  'Paul_Poulet': 40157186,
#  'Jörg_Bewersdorff': 37203806,
#  'Viktor_Vladimirovich_Nemytskii': 35529165,
#  'Infinite-dimensional_vector_function': 27908089,
#  'Irving_Reiner': 32380640,
#  'List_of_integrals_of_rational_functions': 234854,
#  'Abraham_Fraenkel': 528451,
#  'Single-equation_methods_(econometrics)': 4858526,
#  'Philip_Rabinowitz_(mathematician)': 15046429,
#  'Harold_Hotelling': 935621,
#  'László_Babai': 3461604,
#  'Paul_Vincensini_(mathematician)': 54460966,
#  'Gemma_Frisius': 1127316,
#  'Béla_Szőkefalvi-Nagy': 6718996,
#  'John_Charles_Burkill': 33388595,
#  'Robert_McEliece': 2151291,
#  'Constant_amplitude_zero_autocorrelation_waveform': 7252626,
#  'Teofil_Żebrawski': 8003714,
#  'Spin_connection': 2915190,
#  'Where_Mathematics_Comes_From': 45754,
#  'Characteristic_power_series': 37993825,
#  'Probability_Surveys': 22965731,
#  'Vera_Nikolaevna_Maslennikova': 35114105,
#  'Poul_Heegaard': 1138214,
#  'Jerrold_E._Marsden': 6164105,
#  "Scorer's_function": 1092524,
#  'List_of_Chinese_mathematicians': 30654226,
#  'FreeFlyer': 27506488,
#  'Dmitry_Feichtner-Kozlov': 54233101,
#  'Andrey_Markov': 915,
#  'Null_ideal': 30830538,
#  'John_Wermer': 47568103,
#  'John_Robert_Ringrose': 34945448,
#  'Alan_Davies_(mathematician)': 8782995,
#  'Paul_T._Bateman': 26642296,
#  'Unital_map': 29268538,
#  'Wolfgang_R._Wasow': 55289107,
#  'George_Pólya_Prize': 6233334,
#  'Lajos_Pukánszky': 22378202,
#  'Leopold_Schmetterer': 35273712,
#  'Marie_Crous': 32981420,
#  'GEUP': 6561586,
#  'Bernard_Morin': 702848,
#  'Number_Theory_Library': 26907870,
#  'Journal_of_the_European_Mathematical_Society': 30673871,
#  'List_of_planar_symmetry_groups': 2868583,
#  'Hassan_Ugail': 4376698,
#  'Sam_Vandervelde': 13966214,
#  'Étienne_Ghys': 7561937,
#  'Walter_Foster_(mathematician)': 32223313,
#  'Heinrich_Emil_Timerding': 19002553,
#  'Paul_Ernest': 1214276,
#  'Semicomputable_function': 22032894,
#  'Stieltjes_constants': 1479085,
#  'Veniamin_Kagan': 9679792,
#  'European_Society_for_Mathematics_and_the_Arts': 46270431,
#  'Adam_Lonicer': 15733487,
#  'Sandy_Green_(mathematician)': 10670093,
#  'Tux,_of_Math_Command': 14432816,
#  'Thomas_Jakobsen': 9411891,
#  'Arccos(x)': 15118415,
#  'Natalia_Berloff': 53835306,
#  'John_Watt_Butters': 47325627,
#  'Myhill–Nerode_theorem': 339992,
#  "Ulam's_game": 32177562,
#  'Nassif_Ghoussoub': 18739787,
#  'List_of_terms_relating_to_algorithms_and_data_structures': 723738,
#  'Tetracategory': 7301396,
#  'Olof_Thorin': 35269790,
#  'Ƒ(x)': 25283148,
#  "Jacques_d'Allonville": 1437867,
#  'Ellice_Horsburgh': 52249022,
#  'Herbrand_interpretation': 7731831,
#  'Ovidiu_Savin': 39307695,
#  'Arthur_Wieferich': 1560812,
#  'Renu_C._Laskar': 22783396,
#  'Danny_Calegari': 21907908,
#  'Van_Amringe_Mathematical_Prize': 36133589,
#  'Cora_Sadosky': 42346687,
#  'Adrian_Smith_(statistician)': 4097065,
#  'Aḥmad_ibn_Mūsā_ibn_Shākir': 30255708,
#  'Wilfred_Cockcroft': 23270237,
#  'Sienna_Morris': 33255954,
#  'Trygve_Haavelmo': 1071972,
#  'Identity_function': 15069,
#  'List_of_things_named_after_Joseph_Liouville': 49433646,
#  'Rudolf_Hentze': 56472202,
#  'Ralph_Palmer_Agnew': 35221713,
#  'Johann_Faulhaber': 9768822,
#  'Hans_Riesel': 2805218,
#  'F._Thomson_Leighton': 1527871,
#  'Everyday_Mathematics': 9468205,
#  'Michelle_Francl': 11027909,
#  'August_Beer': 307064,
#  'Ib_Madsen': 38416618,
#  'Taught_Course_Centre': 15362663,
#  'Harold_Neville_Vazeille_Temperley': 9512092,
#  'Otto_Blumenthal': 1459902,
#  'Keith_Martin_Ball': 41995729,
#  'Abū_al-Ḥasan_ibn_ʿAlī_al-Qalaṣādī': 8064048,
#  'S._M._Shah': 22900376,
#  'Jean-Charles_della_Faille': 1423365,
#  'Morris_Kline': 826363,
#  'List_of_knot_theory_topics': 2016033,
#  'Marie_Anne_Victoire_Pigeon': 41565420,
#  'Notation_in_probability_and_statistics': 2142734,
#  'Cyclotomic_identity': 429966,
#  "Kuratowski's_closure-complement_problem": 10104622,
#  'Modified_KdV–Burgers_equation': 42063681,
#  'Chvátal–Sankoff_constants': 44374551,
#  'Carlo_Cattaneo_(mathematician)': 43514143,
#  'Quality_&_Quantity': 33675324,
#  'Maurício_Peixoto': 7427536,
#  'Encyclopedia_of_Statistical_Sciences': 7778192,
#  'List_of_things_named_after_James_Joseph_Sylvester': 234310,
#  'Naimark_theorem': 34741192,
#  'Dialling_(mathematics)': 12259343,
#  'Siavash_Shahshahani': 7900483,
#  'Vladimir_Vapnik': 209673,
#  'Mathematics_Presents_Wu-Tang_Clan_&_Friends_Unreleased': 11961345,
#  'Philip_Woodward': 9986270,
#  'Michael_Rapoport': 26629548,
#  'Doron_Zeilberger': 1724825,
#  'Symbolab': 48679499,
#  'PSL(2,C)': 2650835,
#  'Prouhet–Tarry–Escott_problem': 16400356,
#  'Siddhānta_Shiromani': 33459997,
#  'Condensation_point': 19472545,
#  'Alfred_Kneschke': 54009472,
#  'Martin_Barner': 42687455,
#  'Electrocardiography': 76988,
#  'Classical_mathematics': 1178398,
#  'Conrad_Henfling': 36271397,
#  'A_Guide_Book_to_Mathematics:_Formulas,_Tables,_Graphs,_Methods': 50034343,
#  'University_of_Chicago_School_Mathematics_Project': 26837834,
#  'Hiroshi_Toda': 13710063,
#  'Joseph_Sgro': 33792013,
#  'Final_value_theorem': 19884227,
#  'Arthur_P._Dempster': 7040761,
#  'Natashia_Boland': 51468846,
#  'The_Quantum_Rose': 3790344,
#  'Pao_Ming_Pu': 19073260,
#  'Thomas_Chalmers': 554486,
#  'List_of_linear_algebra_topics': 353855,
#  'List_of_polygons,_polyhedra_and_polytopes': 517370,
#  'Alexander_Rinnooy_Kan': 26293316,
#  'Wilson_Sutherland': 52059400,
#  'R._K._Rubugunday': 40027362,
#  "Sylvester's_theorem": 25622209,
#  'Nearest-neighbor_interpolation': 2905498,
#  'Tg_(trigonometry)': 49603441,
#  'Sibt_al-Maridini': 8477832,
#  'Carl_Pomerance': 2134159,
#  'MSU_Faculty_of_Mechanics_and_Mathematics': 5177270,
#  'W._H._Besant': 38744654,
#  'Ludvig_Oppermann': 34849134,
#  'Edward_Jarvis_(physician)': 38892332,
#  'List_of_convexity_topics': 1018951,
#  'De_Thiende': 36193619,
#  'Ralph_Fox': 1343918,
#  'Ioan_Dzițac': 40603574,
#  'Complete_set_of_invariants': 9903220,
#  'Edward_Sang': 30059562,
#  'Index_set': 393055,
#  'The_Wild_Numbers': 50312471,
#  'Claiborne_Latimer': 38451711,
#  'Friedrich_Hartogs': 2977779,
#  'University_of_Sydney_School_of_Mathematics_and_Statistics': 25289759,
#  'Greek_mathematics': 1503369,
#  'James_Wood_(mathematician)': 25831625,
#  'Reinhard_Oehme': 18592503,
#  'Eugenio_Calabi': 621000,
#  "Euclid's_Elements": 244107,
#  'Yuval_Peres': 36477942,
#  'Henk_J._M._Bos': 34568148,
#  'Harry_Dym': 2092501,
#  'Cis(θ)': 49014423,
#  'Riemann_hypothesis': 19344125,
#  'Heisenberg_group': 448518,
#  'Shiu-Yuen_Cheng': 3359154,
#  'Riemann_curvature_tensor': 130526,
#  'Emma_Castelnuovo': 46508864,
#  'Johann_Friedrich_Weidler': 35681613,
#  'Wealthy_Babcock': 48464067,
#  'Gilbert_Clerke': 21722755,
#  "Artstein's_theorem": 14559354,
#  'Couenne': 45487871,
#  'Harry_Clinton_Gossard': 36164235,
#  'Andrey_Nikolayevich_Tikhonov': 616048,
#  'List_of_things_named_after_Pythagoras': 33695362,
#  'Claude_Hardy': 47061939,
#  'Stochastic_discount_factor': 35154313,
#  'All_horses_are_the_same_color': 151912,
#  'Gérard_Cornuéjols': 48001679,
#  'Rolando_Chuaqui': 51390615,
#  'Christopher_D._Sogge': 45131291,
#  'Jill_Pipher': 30887737,
#  'Raman_Parimala': 11853200,
#  'P_Kesava_Menon': 18537948,
#  'Hippocrates_of_Chios': 3632522,
#  'Lam_Lay_Yong': 26926721,
#  'Benedetto_Scotto': 55737095,
#  'School_Mathematics_Project': 3196691,
#  'Lₚ': 42129351,
#  'ArcSin': 7731253,
#  'Heini_Halberstam': 4872223,
#  'Paul_Chester_Kainen': 22674877,
#  'Canonical_quantum_gravity': 3936576,
#  'Aristarchus_of_Samos': 74857,
#  'Chudnovsky_brothers': 1705790,
#  'Ellen_Hayes': 30803079,
#  'Cora_Barbara_Hennel': 55589991,
#  "Abel's_identity": 3261224,
#  'Pietro_Cataldi': 958066,
#  'Chamfered_dodecahedron': 4472133,
#  "Kuhn's_theorem": 42727389,
#  'Ernest_Vessiot': 1142911,
#  'Gerolamo_Cardano': 13145,
#  'William_Batecumbe': 32658301,
#  'A._Stephen_Morse': 48662306,
#  'André_Neves': 46448982,
#  'John_Dawson_(surgeon)': 7896210,
#  'George_Kingsley_Zipf': 768770,
#  'Artin–Mazur_zeta_function': 1342156,
#  'Michael_Aschbacher': 1652651,
#  'Minimal_realization': 1554398,
#  'Józef_H._Przytycki': 1280583,
#  "Friedman's_SSCG_function": 46944668,
#  'Barbara_Goette': 34866410,
#  'OptimJ': 28952622,
#  'Pierre_Pansu': 19383362,
#  'Neil_Trudinger': 15173259,
#  'Gangesha_Upadhyaya': 1163083,
#  'Ivan_Fesenko': 30484997,
#  'De-sparsified_lasso': 47027818,
#  'Algebraic_Geometry_(journal)': 51408141,
#  'Johann_Jakob_Balmer': 768749,
#  'Mathiness': 47197272,
#  'Claude_Mydorge': 2065156,
#  'Edmund_F._Robertson': 20120951,
#  'Gary_Chartrand': 22782409,
#  'List_of_exponential_topics': 490054,
#  "Znám's_problem": 1452979,
#  'Journal_de_Mathématiques_Pures_et_Appliquées': 14565557,
#  'Kazuya_Kato': 4616818,
#  'Arccsc': 3804135,
#  'André_Tacquet': 1423393,
#  'Digital_Bullet': 47437170,
#  'List_of_things_named_after_Alexander_Grothendieck': 39402871,
#  'Claude_Rabuel': 49460387,
#  'Vector_notation': 5959843,
#  'Fangcheng_(mathematics)': 52815653,
#  'Latin_letters_used_in_mathematics': 1978904,
#  'Helen_F._Cullen': 56582673,
#  '＝': 3253381,
#  'Claribel_Kendall': 30836915,
#  'Function_(mathematics)': 185427,
#  'N-topological_space': 39688248,
#  'Matrix_product_state': 42099889,
#  'Courant_minimax_principle': 16704670,
#  'Michio_Jimbo': 22363355,
#  'Approximate_identity': 949628,
#  'Fraunhofer_Society': 197440,
#  'Florian_Neukart': 53786518,
#  'OLGA_(technology)': 27908263,
#  'Constructive_set_theory': 5042360,
#  'Sijue_Wu': 48326992,
#  'Claude_Berge': 5893760,
#  'John_Forbes_Nash_Jr.': 102567,
#  'List_of_trigonometric_identities': 25804104,
#  'Steinhaus–Moser_notation': 305463,
#  'European_Journal_of_Combinatorics': 13378267,
#  'Robert_Harley_(mathematician)': 50938433,
#  'Michael_I._Jordan': 1513732,
#  'Mary_Flahive': 56636978,
#  'Ivan_Vidav': 40443,
#  'Bartholomaeus_Pitiscus': 2685994,
#  'Jean-Pierre_Sydler': 20493975,
#  'Hans_Lewy': 1752415,
#  'Swedish_Institute_of_Computer_Science': 2672495,
#  'Norwegian_Mathematical_Society': 15255049,
#  'Guido_Ascoli': 34947741,
#  'Landau_set': 6152753,
#  'Ellis_Stouffer': 47920944,
#  'Neena_Gupta_(mathematician)': 51441080,
#  'Robert_Connelly': 9070151,
#  'Michael_Scot': 673618,
#  'Witold_Milewski_(mathematician)': 6112007,
#  'Tee_(symbol)': 19145299,
#  'Mike_Develin': 32885497,
#  'Kempner_series': 17961670,
#  'James_Mercer_(mathematician)': 303923,
#  'Marie_Georges_Humbert': 33375250,
#  'Julie_Lutz': 56624208,
#  'Bernard_Koopman': 2023218,
#  "Gabbay's_separation_theorem": 19835615,
#  'Abraham_Charnes': 48705535,
#  'Xn_+_yn': 30724534,
#  'Nataša_Pavlović': 48602662,
#  'Wolfgang_Heinrich_Johannes_Fuchs': 5397705,
#  'Glossary_of_tensor_theory': 369981,
#  'Paul_Scriptoris': 3775233,
#  'Eventually_(mathematics)': 10077292,
#  'Eduard_Looijenga': 45224498,
#  'Unit_doublet': 24129233,
#  'Athanase_Dupré': 28513579,
#  'Alfred_Tarski': 59920,
#  'Laura_Martignon': 54391392,
#  'Gregorio_Ricci-Curbastro': 499223,
#  'Fathi_Shaqaqi': 2597058,
#  'Walter_Tuchman': 2316487,
#  'K._V._Sarma': 23669656,
#  'Patlak_plot': 4921531,
#  'Almost': 253447,
#  'Project_NExT': 14984955,
#  'Mary_Tsingou': 37784250,
#  'John_Senyonyi': 43773045,
#  'Isaac_Namioka': 45199487,
#  'F(g)_Scholar': 27883420,
#  'Generality_of_algebra': 31628660,
#  'Giacinto_Morera': 13253224,
#  "Sperner's_lemma": 465067,
#  'Elisabeth_M._Werner': 45507255,
#  'ℓᵖ': 42144698,
#  'Two_New_Sciences': 268475,
#  'List_of_important_publications_in_statistics': 708879,
#  'John_Kells_Ingram': 6550356,
#  'Nearest_neighbor_search': 7309022,
#  'Krieger–Nelson_Prize': 11851829,
#  'Adolph_Göpel': 18550639,
#  'Stefano_Montaldo': 52949144,
#  'Glossary_of_probability_and_statistics': 2142850,
#  'Nikolai_Andreevich_Lebedev': 19304045,
#  'Taro_Morishima': 7372292,
#  'Alfred_H._Clifford': 22683347,
#  'Soil_production_function': 5499671,
#  'Lawrence_C._Evans': 2790063,
#  'Daniel_da_Silva_(mathematician)': 21372965,
#  'John_Williamson_(mathematician)': 36284380,
#  'Penrose_diagram': 681666,
#  'Math_in_Moscow': 27194034,
#  'Congruent_transformation': 2418403,
#  'Gheorghe_Țițeica': 1518329,
#  'Mark_Naimark': 1417108,
#  'Richard_Beals_(mathematician)': 40775372,
#  'Ruth_Lyttle_Satter_Prize_in_Mathematics': 37554140,
#  'Hafner–Sarnak–McCurley_constant': 9033954,
#  'Amir_Pnueli': 308365,
#  'Math_symbol_parentheses': 43570949,
#  'Dual_norm': 13525027,
#  'Ordinal_logic': 32123297,
#  'Howell_Tong': 22304790,
#  'Kathleen_Ollerenshaw': 872857,
#  'The_American_Statistician': 16876079,
#  'Thomas_Carlyle': 128422,
#  'Stanford_University_Mathematics_Camp': 12711731,
#  'Saturated_measure': 2946366,
#  'Joseph_Fourier': 25767401,
#  'The_Fractal_Geometry_of_Nature': 29229128,
#  'G._Spencer-Brown': 37941963,
#  'Steven_Brams': 174860,
#  'Square–cube_law': 1730659,
#  'Book_of_Lemmas': 17941791,
#  'Ethnomathematics': 324872,
#  'Paul_Finsler': 27007280,
#  'Nancy_E._Heckman': 55542068,
#  'Lin–Kernighan_heuristic': 8818888,
#  'Alexander_Abian': 5239250,
#  'Carl_Johannes_Thomae': 30818082,
#  'Russo–Vallois_integral': 8919563,
#  'Up_to': 44787,
#  'Yuri_Zhuravlyov_(mathematician)': 41259162,
#  'Joan_Leitzel': 47027369,
#  'Joseph_Slepian': 17583999,
#  'Hubert_Kennedy': 15414933,
#  'András_Vasy': 52321031,
#  'Masamichi_Takesaki': 41007469,
#  'Toy_theorem': 1458024,
#  'Four_Horsemen_of_the_Apocalypse_(blackjack)': 52793931,
#  'Max_Karoubi': 30942178,
#  'Franklin_P._Peterson': 40839653,
#  'Paul_Dedecker': 42554584,
#  'Dorothy_Lewis_Bernstein': 7097637,
#  'Henry_Hickman_Harte': 29800896,
#  'John_Meadows_Jackson': 52827111,
#  'Local_flatness': 12941444,
#  'Murray_R._Spiegel': 32392859,
#  'Auto-Latex_Equations': 49254217,
#  'Functional_decomposition': 11691,
#  'Cai_Yong': 4684502,
#  'Stanko_Bilinski': 44812552,
#  'Michael_R._Douglas': 683604,
#  'Mayme_Logsdon': 48917058,
#  'Maurice_A._de_Gosson': 33285002,
#  'George_Walker_(mathematician)': 25746123,
#  'Paul_Mansion': 55811631,
#  'José_de_Jesús_Martínez': 48504779,
#  'Roland_Bulirsch': 39317783,
#  'Dana_Scott': 161875,
#  'List_of_differential_geometry_topics': 345396,
#  'Otto_Frostman': 34049712,
#  'ERCIM_Cor_Baayen_Award': 47339689,
#  'The_Mathematics_Enthusiast': 31831187,
#  'Louis_Poinsot': 764639,
#  'Roger_Joseph_Boscovich': 23747676,
#  'Charles_Wells_(mathematician)': 34749968,
#  'Fern_Hunt': 44341949,
#  'Stefan_Burr': 26467605,
#  'Separating_set': 13972359,
#  'Arvind_Raghunathan': 10802246,
#  'SmartDO': 38695146,
#  'Trilinos': 8726769,
#  'James_Robert_McConnell': 41350999,
#  'A_Hill_on_the_Dark_Side_of_the_Moon': 42156700,
#  'Paul_Dubreil': 1389591,
#  'Henry_Moseley_(mathematician)': 40756330,
#  'Gaston_Tarry': 473996,
#  'Eugenio_Giuseppe_Togliatti': 20705284,
#  'Roland_Fraïssé': 4234672,
#  'Tin-Tin_Kyrano': 23910367,
#  'Imre_Z._Ruzsa': 21280618,
#  'David_Balding': 7284519,
#  'Reuben_Burrow': 28094447,
#  'List_of_mathematicians_(M)': 5971818,
#  'Financial_econometrics': 1626747,
#  'Anton_Davidoglu': 3421491,
#  'Chandra_Wickramasinghe': 1773934,
#  'Ronald_Fisher': 140824,
#  'Benson_Farb': 32518776,
#  'Ruggiero_Torelli': 51289873,
#  'R._Tyrrell_Rockafellar': 26300644,
#  'Anton_Zorich': 45625319,
#  'Yasuaki_Aida': 1271126,
#  'Michael_Lvovitch_Tsetlin': 37832091,
#  'Andrew_Beal': 1395328,
#  'Hao_Wang_(academic)': 1056047,
#  'Bojidar_Spiriev': 26133452,
#  'Macaulay_brackets': 11940501,
#  'Frank_Natterer': 36388785,
#  'Function_approximation': 336897,
#  'Kenneth_Arrow': 49894,
#  'Richard_Montague': 610182,
#  'Victor_Zalgaller': 4235763,
#  'Lychrel_number': 1358112,
#  'Economic_data': 322317,
#  'Edmund_Husserl': 9518,
#  'Stjepan_Gradić': 5152807,
#  'Metamathematics': 183508,
#  'Open_Mathematics': 28140878,
#  'Victor_Goryunov': 24354494,
#  'Dunham_Jackson': 7364025,
#  'Evelyn_Boyd_Granville': 5827598,
#  'Jamal_Nazrul_Islam': 7713219,
#  'Gerald_Teschl': 28661853,
#  'Max_August_Zorn': 19740,
#  'List_of_lemmas': 599970,
#  'John_Lehoczky': 53916487,
#  'John_Stillwell': 15066763,
#  'Ibn_al-Haytham': 1645,
#  'Leslie_Fox_Prize_for_Numerical_Analysis': 15366214,
#  'Hilbert–Poincaré_series': 17006296,
#  'Potential_function': 582529,
#  'Georg_Scheffers': 31778680,
#  'Gerhard_Frey': 1021312,
#  'Mitali_Mukerji': 42219025,
#  'László_Fejes_Tóth': 2388442,
#  'Laurent_C._Siebenmann': 13498931,
#  'Frank_Ruskey': 33272681,
#  'Howard_Garland': 47997007,
#  'Luchezar_L._Avramov': 45021966,
#  'Bradley_Efron': 7250868,
#  'Fiber_derivative': 10605275,
#  'Yudell_Luke': 4580785,
#  'Vittorio_Fossombroni': 3126271,
#  'Penrose_tiling': 26611936,
#  'Dominique_Bakry': 44572547,
#  'British_Society_for_the_History_of_Mathematics': 7795793,
#  'Zero–one_law': 890891,
#  'Ágoston_Scholtz': 55893641,
#  'Lajos_Pósa_(mathematician)': 22874054,
#  'Holomorphic_tangent_space': 27540773,
#  'Isaac_Todhunter': 206507,
#  'Ernest_de_Jonquières': 12071279,
#  'Arctan2': 21112160,
#  'Vladimir_Platonov': 905909,
#  'Absolute_Infinite': 3231,
#  'Mixed_complementarity_problem': 6439136,
#  'Parameter': 25065,
#  'Generalized_method_of_moments': 1975550,
#  'Pfeffer_integral': 18547070,
#  'Gregor_Wentzel': 8100183,
#  'Edward_O._Thorp': 1626719,
#  'Edgar_Gilbert': 30980291,
#  'Richard_A._Parker': 4582441,
#  'Tiberiu_Popoviciu_Institute_of_Numerical_Analysis': 51408178,
#  'Space_(mathematics)': 5308894,
#  'Jürgen_Jost': 41172240,
#  'Corollary': 168865,
#  'Charles_Clayton_Grove': 35283405,
#  'Quantum_geometry': 681895,
#  'Shigeru_Iitaka': 42539147,
#  'Corwin_Hansch': 1403024,
#  'Thomas_Bond_Sprague_Prize': 38576605,
#  'Rule_of_product': 1594286,
#  'Reverse_Polish_notation': 26513,
#  'Eugenio_Beltrami': 543760,
#  'Edmond_Laguerre': 1011080,
#  'Carl_Neumann': 915551,
#  "Indra's_Pearls_(book)": 8704195,
#  'Ineke_De_Moortel': 56590405,
#  'Arnaldo_Garcia': 47360905,
#  'Formula_calculator': 17136006,
#  'Kayles': 18869317,
#  'Non-surveyable_proof': 48740815,
#  'Lloyd_N._Trefethen': 7309909,
#  'Barry_Pennington': 23991497,
#  'Australian_Science_and_Mathematics_School': 2224738,
#  'Jaroslav_Nešetřil': 6948446,
#  'Hölder_summation': 41694231,
#  'Shing-Tung_Yau': 303137,
#  'Encyclopedia_of_Life_Support_Systems': 1065199,
#  'Eiπ': 30838160,
#  'Honoré_Fabri': 15965580,
#  'Richard_Taylor_(mathematician)': 646931,
#  'Dodgem': 4327086,
#  'Karanapaddhati': 25779986,
#  'Infosys_Prize': 22856302,
#  'Square_knot_(mathematics)': 26666011,
#  'Danilo_Blanuša': 474117,
#  'Mathematics_and_architecture': 279293,
#  'Vector_spherical_harmonics': 16589498,
#  'Fundamenta_nova_theoriae_functionum_ellipticarum': 37312651,
#  'Proper_order': 54709544,
#  'Richard_Elman_(mathematician)': 39905714,
#  'Antiquarian_science_books': 20860737,
#  'Harry_Kesten': 19816546,
#  'Stanisław_Jaśkowski': 4304907,
#  'Michèle_Audin': 32743787,
#  'Arithmetic_for_Parents': 22225493,
#  'Arcctg_(trigonometric_function)': 49636486,
#  'Julian_Keilson': 14466539,
#  'Additional_Mathematics': 26673495,
#  "Tarski's_problem": 16066456,
#  'Hermann_Rothe': 18568899,
#  'Water_pouring_puzzle': 48058843,
#  "Chen's_theorem": 1400840,
#  'List_of_permutation_topics': 3553599,
#  'Johannes_Hjelmslev': 30961758,
#  'Algebraic_sentence': 24497678,
#  'Moore–Smith_limit': 23409880,
#  'Imre_Bárány': 22885538,
#  "Na'im_ibn_Musa": 31327881,
#  'Conway_Berners-Lee': 2913296,
#  'Mental_abacus': 980831,
#  'Dragan_Marušič': 169311,
#  'Kaplan–Yorke_map': 2053018,
#  'Louis_Weisner': 32809748,
#  'Nonelementary_integral': 1520379,
#  'William_B._Johnson_(mathematician)': 38341443,
#  'WRF-SFIRE': 42596301,
#  'Communications_in_Algebra': 48037177,
#  'Scale-free_network': 227155,
#  'Dennis_Sullivan': 7349608,
#  'Transcendental_equation': 6073963,
#  'Null_sign': 22965711,
#  'Prescribed_Ricci_curvature_problem': 15895901,
#  'IPOPT': 2848660,
#  'Carl-Gustav_Esseen': 27147478,
#  'Herbert_A._Hauptman': 1262909,
#  'Alexander_Oppenheim': 5325682,
#  'Vilhelm_Herman_Oluf_Madsen': 5475409,
#  'WIRIS': 37842037,
#  'Centrum_Wiskunde_&_Informatica': 506063,
#  'Tsit_Yuen_Lam': 38211016,
#  'Math_circle': 5163815,
#  'Developable': 3196647,
#  'Multi-spectral_phase_coherence': 50141934,
#  'Winifred_Edgerton_Merrill': 7253791,
#  'Sadratnamala': 25469312,
#  'Jacobi_transform': 54328391,
#  'Octal_game': 20219061,
#  'Aksel_Frederik_Andersen': 35228823,
#  '.9..._=_1': 52993300,
#  'William_Magan_Campion': 44331754,
#  'Gary_Gibbons': 2532138,
#  'Carlos_Graef_Fernández': 52582631,
#  'Johan_Galtung': 396339,
#  'Glossary_of_areas_of_mathematics': 34189212,
#  'Literal_(mathematical_logic)': 7792761,
#  'Thomas_Little_Heath': 257230,
#  'Johann_Heinrich_Louis_Krüger': 50761944,
#  'Werner_Fenchel': 4784468,
#  'Rigid_graph': 25730509,
#  'Vaclav_Zizler': 1917608,
#  'Donald_A._S._Fraser': 46584798,
#  'Ed_Posner': 47674352,
#  'Elizabeth_S._Allman': 44749903,
#  'TOMVIEW': 17451177,
#  'Fuzzy_sphere': 3031585,
#  'Karl-Otto_Stöhr': 47360932,
#  'Humphrey_Baker': 30389964,
#  'Barry_Mazur': 23087679,
#  'Glossary_of_shapes_with_metaphorical_names': 7041824,
#  'Point_(geometry)': 593693,
#  'Lebombo_bone': 36552488,
#  'Cylindroid': 9485655,
#  'Algebraic_structure': 106364,
#  'Littlewood–Offord_problem': 1976420,
#  'Edna_Kramer': 15417234,
#  'Gell-Mann_matrices': 563694,
#  'Shriek_map': 22629996,
#  'Aleksey_Krylov': 2656959,
#  'Optimization_Toolbox': 39832690,
#  'Connection_(fibred_manifold)': 39377900,
#  'PCLake': 34995809,
#  'K-Poincaré_algebra': 18193964,
#  'Uniform_field_theory': 29749902,
#  'Victor_Buchstaber': 5288311,
#  'Giovanni_Battista_Pisani': 49809215,
#  'Josip_Plemelj': 40441,
#  'Suzanne_Lenhart': 46919225,
#  'List_of_shapes_with_known_packing_constant': 43530822,
#  'Mechanica': 19934255,
#  'Zhang_Heng': 34542,
#  'Schoen–Yau_conjecture': 8238857,
#  'St._Petersburg_Department_of_Steklov_Institute_of_Mathematics_of_Russian_Academy_of_Sciences': 16031996,
#  'Radical_symbol': 24971503,
#  'William_Messing': 35349915,
#  'Efficient_frontier': 28197279,
#  'Donald_Kingsbury': 1023362,
#  'Khairulla_Murtazin': 43965386,
#  'Paul_Funk': 30891789,
#  'Full_and_faithful_functors': 876534,
#  "Wigner's_classification": 309392,
#  'Malay_Ghosh': 38548751,
#  'Variable_and_attribute_(research)': 30423282,
#  'Rinad_Yulmukhametov': 44022631,
#  'Gjon_Gazulli': 14438257,
#  'Monika_Ludwig': 38459575,
#  'Charles_Étienne_Louis_Camus': 2977925,
#  "Chow's_moving_lemma": 38307346,
#  'Ludwig_Becker_(astronomer)': 42122244,
#  'Leonard_James_Rogers': 9024921,
#  'Pietro_Paoli': 47868477,
#  'Anthony_Morse': 25274723,
#  'The_Penguin_Dictionary_of_Curious_and_Interesting_Numbers': 27576059,
#  'Cis(z)': 49132247,
#  'Stephanie_Singer': 46420296,
#  'Karel_Petr': 4436275,
#  'Johann_Friedrich_Pfaff': 1669324,
#  'Vanishing_theorem': 22999113,
#  "Zhao_Youqin's_π_algorithm": 43132260,
#  'Karl_Menninger_(mathematics)': 5496919,
#  'Polyadic_algebra': 22737733,
#  'William_Gemmell_Cochran': 2223833,
#  'Alan_Weinstein': 7344764,
#  '(ε,_δ)-definition_of_limit': 19216956,
#  'Timur_Eneev': 40165500,
#  'Fritz_Carlson': 5094208,
#  'Quantum_ergodicity': 23855903,
#  'Edward_Walker_(mathematician)': 54548536,
#  'Euler–Poisson–Darboux_equation': 16703428,
#  'George_Glauberman': 9744285,
#  'Simple_Grapher': 48697256,
#  'Liliana_Borcea': 54249520,
#  'Diffeology': 159587,
#  'Glossary_of_field_theory': 291644,
#  'Reinhard_Selten': 212034,
#  'Collectanea_Mathematica': 51692871,
#  'Peter_A._Loeb': 31352141,
#  'Fast_sweeping_method': 51959005,
#  'The_Library_of_Babel': 192303,
#  'László_Lempert': 22978185,
#  'Geometric_median': 10324687,
#  'Tom_Lehrer': 30951,
#  'Honest_leftmost_branch': 7651308,
#  'Scalar-vector-tensor_decomposition': 3998066,
#  'Sze-Tsen_Hu': 48407740,
#  "Tables_d'intégrales_définies": 50246640,
#  'Nicholas_Higham': 10011004,
#  '21_(2008_film)': 10433895,
#  'Cross_product': 157092,
#  'Magic_hyperbeam': 13353185,
#  'Haynes_Miller': 36472512,
#  'Salomon_Bochner': 987847,
#  'Aleksandr_Kotelnikov': 29545496,
#  'Mikhail_Shubin_(mathematician)': 23229760,
#  'Jacob_T._Schwartz': 2182070,
#  'Semi-simple_operator': 7252030,
#  "Tarski's_theorem_about_choice": 320578,
#  'Victor_Andreevich_Toponogov': 12957669,
#  'Squared_triangular_number': 4924488,
#  'Advances_in_Applied_Mathematics': 30498353,
#  'Adhémar_Jean_Claude_Barré_de_Saint-Venant': 5878555,
#  'Charles_Macdonald_(professor)': 55327682,
#  "Folkman's_theorem": 29265641,
#  'AStA_Advances_in_Statistical_Analysis': 30755788,
#  '8_19_knot': 39454827,
#  'Jan_Bruinier': 56625234,
#  'Ott-Heinrich_Keller': 1193984,
#  'Baire_measure': 13520509,
#  'List_of_integrals_of_logarithmic_functions': 234985,
#  'Robert_M._Anderson_(mathematician)': 34366033,
#  'Three-dimensional_graph': 53345929,
#  'Arcsin': 2559940,
#  'Set_notation': 2804687,
#  'Robert_Hermann_(mathematician)': 37160480,
#  'René_Taton': 33590159,
#  "Khinchin's_constant": 435315,
#  'Mathematics_in_Education_and_Industry': 11024216,
#  'George_Gibson_(mathematician)': 50996810,
#  'Glossary_of_graph_theory_terms': 325802,
#  'Juan_de_Ortega_(mathematician)': 55819509,
#  'Konrad_Jörgens': 34870269,
#  'Julius_Richard_Büchi': 6736044,
#  'Cumulative_accuracy_profile': 54727095,
#  'Lex_de_Haan': 11074849,
#  'W._Edwards_Deming': 70534,
#  'William_George_Horner': 998647,
#  'Alister_George_McLellan': 43478581,
#  'Networks_and_Spatial_Economics': 13633191,
#  'Jean-Baptiste_Biot': 75109,
#  'Francesco_Cetti': 401137,
#  'Seventh-order_Korteweg–de_Vries_equation': 42063325,
#  'Nathan_Mendelsohn': 17591841,
#  'Warren_Ewens': 2095764,
#  'Ruth_Lawrence': 670436,
#  'Daniel_D._McCracken': 5666643,
#  'DNA_sequencing_theory': 19287844,
#  'Sphereland': 1514300,
#  '1782^12_+_1841^12_=_1922^12': 12574138,
#  'Matthew_Cook': 145310,
#  'Summability_kernel': 42625595,
#  'Al-Nayrizi': 1782819,
#  ...}

# %%
import networkx as nx

# %%
D = nx.DiGraph()
D.add_edges_from(links)

# %%
len(D)
# Out:
# 15414

# %%
len(links)
# Out:
# 194368

# %%
len(page_ids)
# Out:
# 15992

# %%
min(D.in_degree, key=lambda x: x[1])
# Out:
# (45285384, 0)

# %%
for title, page_id in page_titles.items():
    try:
        D.node[page_id]['title'] = title
    except KeyError:
        pass

# %%
nx.write_graphml(D, 'enwiki_math.graphml.gz')

# %% [markdown]
# # Resolve redirects

# %%
result = engine.execute('select page_id from math_page where page_is_redirect = 1')
redirect_ids = [x[0] for x in result]
len(redirect_ids)
# Out:
# 411

# %%
for n in redirect_ids:
    if n in D:
        successors = list(D.successors(n))
        if len(successors) > 1:
            raise('%i has >1 successor')
        if len(successors) == 1:
            target = successors[0]
            for source in D.predecessors(n):
                D.add_edge(source, target)
        D.remove_node(n)

# %%
nx.write_graphml(D, 'enwiki_math.graphml.gz')

# %%
len(D)
# Out:
# 15220

# %%
sorted(D.degree, key=lambda x: x[1], reverse=True)[:5]
# Out:
# [(1152126, 5181),
#  (18831, 4987),
#  (18902, 4198),
#  (1485646, 2084),
#  (198822, 1683)]

# %%
D.node[198822]['title']
# Out:
# 'American_Mathematical_Society'
